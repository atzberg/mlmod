# %% [markdown]
# ### Example for how to use PyTorch models for MLMOD-LAMMPS simulations.
# Paul J. Atzberger <br>
# http://atzberger.org

# %% [markdown]
# #### Import packages

# %%
# Shows how to run a simulation in LAMMPS using the PyTorch models.
import os,sys;
import shutil;
import numpy as np;
import pickle;
script_base_name = "run_mlmod_sim1";
script_dir = os.getcwd();

# %%
# import the mlmod_lammps module
from mlmod_lammps.lammps import IPyLammps # use this for the pip install of pre-built package
lammps_import_comment = "from mlmod_lammps.lammps import IPyLammps";

# %% [markdown]
# #### Define local functions

# %%
# filesystem management
def create_dir(dir_name):
  if not os.path.exists(dir_name):
    os.makedirs(dir_name);    
    
def rm_dir(dir_name):
  if os.path.exists(dir_name):    
    shutil.rmtree(dir_name);
  else: 
    print("WARNING: rm_dir(): The directory does not exist, dir_name = " + dir_name);    

def copytree2(src, dst, symlinks=False, ignore=None):
  for ff in os.listdir(src):
    s = os.path.join(src, ff); d = os.path.join(dst, ff);
    if os.path.isdir(s):
      shutil.copytree(s, d, symlinks, ignore);
    else:
      shutil.copy2(s, d);

# %% [markdown]
# #### Test the package

# %%
print("Testing library loaded...");
flag=True;
if flag:
  from mlmod_lammps.tests import t1; t1.test()
# Out:
# Testing library loaded...
# Create Lammps session:
# LAMMPS output is captured by PyLammps wrapper
# Show Lammps information:
# LAMMPS (29 Oct 2020)
#
# Info-Info-Info-Info-Info-Info-Info-Info-Info-Info-Info
# Printed on Fri Sep 23 20:46:17 2022
#
#
# LAMMPS version: 29 Oct 2020 / 20201029
#
# OS information: Linux 5.15.0-48-generic on x86_64
#
# sizeof(smallint): 32-bit
# sizeof(imageint): 32-bit
# sizeof(tagint):   32-bit
# sizeof(bigint):   64-bit
#
# Compiler: GNU C++ 6.3.0 20170516 with OpenMP not enabled
# C++ standard: C++14
#
# Active compile time flags:
#
# -DLAMMPS_GZIP
# -DLAMMPS_PNG
# -DLAMMPS_JPEG
# -DLAMMPS_FFMPEG
# -DLAMMPS_EXCEPTIONS
# -DLAMMPS_SMALLBIG
#
# Installed packages:
#
# MOLECULE USER-MISC USER-VTK
#
# Memory allocation information (MPI rank 0):
#
# Total dynamically allocated memory: 0.02355 Mbyte
# Current reserved memory pool size: 43.59 Mbyte
# Maximum resident set size: 157.3 Mbyte
#
# Communication information:
# MPI library level: MPI v1.2
# MPI version: LAMMPS MPI STUBS for LAMMPS version 29 Oct 2020
# Comm style = brick,  Comm layout = uniform
# Communicate velocities for ghost atoms = no
# Nprocs = 1,   Nthreads = 1
#
# System information:
# Units         = lj
# Atom style    = atomic
# Atom map      = none
# Atoms     =            0,  types =        0,  style = none
# Kspace style = none
#
# Box has not yet been created
#
# Group information:
# Group[ 0]:     all              (static)
#
# Region information:
#
# Compute information:
# Compute[  0]:  thermo_temp,      style = temp,             group = all
# Compute[  1]:  thermo_press,     style = pressure,         group = all
# Compute[  2]:  thermo_pe,        style = pe,               group = all
#
# Dump information:
#
# Fix information:
#
# Variable information:
#
# Total time information (MPI rank 0):
#   CPU time:    0:00:01
#  Wall time:    0:00:00
#
# Styles information:
#
# Atom styles:
#
# angle           atomic          body            bond            charge
# ellipsoid       full            hybrid          line            molecular
# sphere          template        tri
#
#
#
# Integrate styles:
#
# respa           verlet
#
#
#
# Minimize styles:
#
# cg              fire            fire/old        hftn            quickmin
# sd
#
#
#
# Pair styles:
#
# agni            beck            born            born/coul/dsf   born/coul/wolf
# buck            buck/coul/cut   buck/mdf        cosine/squared  coul/cut
# coul/debye      coul/diel       coul/dsf        coul/shield     coul/slater/cut
# coul/slater/long                coul/streitz    coul/wolf       dpd
# dpd/tstat       drip            e3b             edip            edip/multi
# extep           gauss           gauss/cut       hbond/dreiding/lj
# hbond/dreiding/morse            hybrid          hybrid/overlay  ilp/graphene/hbn
# kolmogorov/crespi/full          kolmogorov/crespi/z             lebedeva/z
# lennard/mdf     list            lj/charmm/coul/charmm
# lj/charmm/coul/charmm/implicit  lj/charmmfsw/coul/charmmfsh     lj/cubic
# lj/cut          lj/cut/coul/cut lj/cut/coul/debye               lj/cut/coul/dsf
# lj/cut/coul/wolf                lj/cut/tip4p/cut                lj/expand
# lj/expand/coul/long             lj/gromacs      lj/gromacs/coul/gromacs
# lj/mdf          lj/sf           lj/sf/dipole/sf lj/smooth       lj/smooth/linear
# lj96/cut        local/density   meam/spline     meam/sw/spline  mie/cut
# momb            morse           morse/smooth/linear             reax
# soft            srp             table           tersoff/table   tip4p/cut
# ufm             yukawa          zbl             zero
#
#
#
# Bond styles:
#
# fene            fene/expand     gromos          harmonic        harmonic/shift
# harmonic/shift/cut              hybrid          morse           nonlinear
# quartic         special         table           zero
#
#
#
# Angle styles:
#
# charmm          cosine          cosine/delta    cosine/periodic cosine/shift
# cosine/shift/exp                cosine/squared  dipole          fourier
# fourier/simple  harmonic        hybrid          quartic         table
# zero
#
#
#
# Dihedral styles:
#
# charmm          charmmfsw       cosine/shift/exp                fourier
# harmonic        helix           hybrid          multi/harmonic  nharmonic
# opls            quadratic       spherical       table           table/cut
# zero
#
#
#
# Improper styles:
#
# cossq           cvff            distance        fourier         harmonic
# hybrid          ring            umbrella        zero
#
#
#
# KSpace styles:
#
#
#
#
# Fix styles:
#
# accelerate/cos  adapt           addforce        addtorque       ave/atom
# ave/chunk       ave/correlate   ave/correlate/long              ave/histo
# ave/histo/weight                ave/spatial     ave/spatial/sphere
# ave/time        aveforce        balance         box/relax       cmap
# controller      deform          drag            dt/reset
# electron/stopping               enforce2d       external        ffl
# filter/corotate flow/gauss      gle             gravity         grem
# halt            heat            imd             indent          ipi
# langevin        lineforce       mlmod           momentum        momentum/chunk
# move            nph             nph/sphere      npt             npt/cauchy
# npt/sphere      numdiff         nve             nve/limit       nve/noforce
# nve/sphere      nvk             nvt             nvt/sllod       nvt/sphere
# orient/eco      pafi            pimd            planeforce      press/berendsen
# print           propel/self     property/atom   recenter        restrain
# rhok            selm            setforce        smd             spring
# spring/chunk    spring/rg       spring/self     store/force     store/state
# temp/berendsen  temp/csld       temp/csvr       temp/rescale    ti/spring
# tmd             ttm/mod         vector          viscous         wall/ees
# wall/harmonic   wall/lj1043     wall/lj126      wall/lj93       wall/morse
# wall/reflect    wall/reflect/stochastic         wall/region     wall/region/ees
#
#
#
# Compute styles:
#
# ackland/atom    adf             aggregate/atom  angle           angle/local
# angmom/chunk    basal/atom      bond            bond/local      centro/atom
# centroid/stress/atom            chunk/atom      chunk/spread/atom
# cluster/atom    cna/atom        cnp/atom        com             com/chunk
# contact/atom    coord/atom      dihedral        dihedral/local  dipole/chunk
# displace/atom   entropy/atom    erotate/sphere  erotate/sphere/atom
# fragment/atom   global/atom     group/group     gyration        gyration/chunk
# gyration/shape  gyration/shape/chunk            heat/flux       hexorder/atom
# hma             improper        improper/local  inertia/chunk   ke
# ke/atom         momentum        msd             msd/chunk       omega/chunk
# orientorder/atom                pair            pair/local      pe
# pe/atom         pressure        pressure/cylinder               property/atom
# property/chunk  property/local  rdf             reduce          reduce/chunk
# reduce/region   slice           stress/atom     stress/mop
# stress/mop/profile              stress/mop_selm stress/mop_selm/profile
# temp            temp/chunk      temp/com        temp/deform     temp/partial
# temp/profile    temp/ramp       temp/region     temp/rotate     temp/sphere
# torque/chunk    vacf            vcm/chunk       viscosity/cos
#
#
#
# Region styles:
#
# block           cone            cylinder        intersect       plane
# prism           sphere          union
#
#
#
# Dump styles:
#
# atom            cfg             custom          dcd             image
# local           movie           vtk             xyz
#
#
#
# Command styles (add-on input script commands):
#
# balance         change_box      create_atoms    create_bonds    create_box
# delete_atoms    delete_bonds    displace_atoms  info            minimize
# read_data       read_dump       read_restart    replicate       rerun
# reset_ato

# %% [markdown]
# #### Setup the output directory

# %%
# @base_dir
base_dir_output   = '%s/output/%s'%(script_dir,script_base_name);
create_dir(base_dir_output);

dir_run_name = 'batch_00';
base_dir = '%s/%s_test001'%(base_dir_output,dir_run_name);

# remove all data from dir
rm_dir(base_dir);

# setup the directories
base_dir_fig    = '%s/fig'%base_dir;
create_dir(base_dir_fig);

base_dir_vtk    = '%s/vtk'%base_dir;
create_dir(base_dir_vtk);
# Out:
# WARNING: rm_dir(): The directory does not exist, dir_name = /media/atzberg/InternalHD1/Files_Shared_Windows_Linux/research/Mango-Selm/SELM-LAMMPS/lammps_2021_May_pull_request/examples/USER/mlmod/ex_M_Q1_1_Pair/mlmod_model1/output/run_mlmod_sim1/batch_00_test001

# %% [markdown]
# #### Copy data to the simulation directory

# %%
# print the import comment
print(lammps_import_comment);

# copy the model files to the destination
src = script_dir + '/' + "mlmod_model1";
dst = base_dir + '/';
copytree2(src,dst,symlinks=False,ignore=None);

# change directory for running LAMMPS in output
print("For running LAMMPS changing the current working directory to:\n%s"%base_dir);
os.chdir(base_dir); # base the current working directory
# Out:
# from mlmod_lammps.lammps import IPyLammps
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [11], line 7
#       5 src = script_dir + '/' + "mlmod_model1";
#       6 dst = base_dir + '/';
# ----> 7 copytree2(src,dst,symlinks=False,ignore=None);
#       9 # change directory for running LAMMPS in output
#      10 print("For running LAMMPS changing the current working directory to:\n%s"%base_dir);
#
# Cell In [8], line 13, in copytree2(src, dst, symlinks, ignore)
#      12 def copytree2(src, dst, symlinks=False, ignore=None):
# ---> 13   for ff in os.listdir(src):
#      14     s = os.path.join(src, ff); d = os.path.join(dst, ff);
#      15     if os.path.isdir(s):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/atzberg/InternalHD1/Files_Shared_Windows_Linux/research/Mango-Selm/SELM-LAMMPS/lammps_2021_May_pull_request/examples/USER/mlmod/ex_M_Q1_1_Pair/mlmod_model1/mlmod_model1'

# %% [markdown]
# #### Setup LAMMPs

# %%
L = IPyLammps();
# Out:
# LAMMPS output is captured by PyLammps wrapper

# %% [markdown]
# #### Show the LAMMPS script

# %%
# Show the LAMMPS script commands that will be run
# read the LAMMPS command file
LAMMPS_script_filename = 'Model.LAMMPS_script';
print("Running script, LAMMPS_script_filename = " + LAMMPS_script_filename);
print(80*"=");
print("LAMMPS_script = " + LAMMPS_script_filename);
print(80*"-");
f = open(LAMMPS_script_filename,'r');
file_lines = f.readlines();
for line in file_lines:
  sys.stdout.write(line);
f.close();
print(80*"=");
# Out:
# Running script, LAMMPS_script_filename = Model.LAMMPS_script
# ================================================================================
# LAMMPS_script = Model.LAMMPS_script
# --------------------------------------------------------------------------------
# # =========================================================================
# # LAMMPS main parameter file and script
# #
# # Author: Paul J. Atzberger.
# #
# # Based on script generated by SELM Model Builder.
# #
# # =========================================================================
#
# # == Setup variables for the script
#
# variable dumpfreq         equal    1
# variable restart          equal    0
# variable neighborSkinDist equal    1.0 # distance for bins beyond force cut-off (1.0 = 1.0 Ang for units = real)
# variable baseFilename     universe Model
#
# # == Setup the log file
# #log         ${baseFilename}.LAMMPS_logFile
#
# # == Setup style of the run
#
# # type of units to use in the simulation (units used are in fact: amu, nm, ns, Kelvins)
# units       nano
#
# # indicates possible types allowed for interactions between the atoms
# atom_style  angle
#
# # indicates possible types allowed for bonds between the atoms
# bond_style  none
#
# # indicates possible types allowed for bond angles between the atoms
# angle_style none
#
# # indicates type of boundary conditions in each direction (p = periodic)
# boundary p p p
#
# read_data ${baseFilename}.LAMMPS_read_data # file of atomic coordinates and topology
# velocity all zero linear                   # initialize all atomic velocities initially to zero
#
# # == Interactions
# pair_style none
# atom_modify sort 1000 ${neighborSkinDist}          # setup sort data explicitly since no interactions to set this data.
#
# # == Setup neighbor list distance
# comm_style tiled
# comm_modify mode single cutoff 18.0 vel yes
#
# neighbor ${neighborSkinDist} bin                    # first number gives a distance beyond the force cut-off ${neighborSkinDist}
# neigh_modify every 1
# atom_modify sort 0 ${neighborSkinDist}           # setup sort data explicitly since no interactions to set this data.
#
# #---------------------------------------------------------
# # == Setup the MLMOD Integrator and Simulation
# fix f1 all mlmod Main.MLMOD_params
#
# # == Setup a fixed force acting on subset of particles
# group cforce id 13 # create group using id's
# fix f2 cforce addforce 10.0 0.0 0.0 # add force to the cforce group
#
# # note langevin just computes forces, nve integrates the motions
# #fix 1 all langevin 298.15 298.15 0.00001 48279
# #fix 2 all nve
#
# # == Setup output data write to disk
# dump        dmp_vtk_mlmod all vtk ${dumpfreq} ./vtk/Particles_mlmod_*.vtp id type vx fx
# #dump        dmp_vtk_mlmod all vtk ${dumpfreq} ./vtk/Particles_langevin_*.vtp id type vx fx
# dump_modify dmp_vtk_mlmod pad 8 # ensures filenames file_000000.data
#
# # == simulation time-stepping
# timestep 0.35
#
# # == Run the simulation
# run      100 upto
#
# ================================================================================

# %% [markdown]
# #### Perform the simulation

# %%
# run by feeding commands to LAMMPs one line at a time
print("Sending commands to LAMMPs");
f = open(LAMMPS_script_filename,'r');
file_lines = f.readlines();
for line in file_lines:
  sys.stdout.write(line);
  L.command(line);
# Out:
# Sending commands to LAMMPs
# # =========================================================================
# # LAMMPS main parameter file and script
# #
# # Author: Paul J. Atzberger.
# #
# # Based on script generated by SELM Model Builder.
# #
# # =========================================================================
#
# # == Setup variables for the script
#
# variable dumpfreq         equal    1
# variable restart          equal    0
# variable neighborSkinDist equal    1.0 # distance for bins beyond force cut-off (1.0 = 1.0 Ang for units = real)
# variable baseFilename     universe Model
#
# # == Setup the log file
# #log         ${baseFilename}.LAMMPS_logFile
#
# # == Setup style of the run
#
# # type of units to use in the simulation (units used are in fact: amu, nm, ns, Kelvins)
# units       nano
#
# # indicates possible types allowed for interactions between the atoms
# atom_style  angle
#
# # indicates possible types allowed for bonds between the atoms
# bond_style  none
#
# # indicates possible types allowed for bond angles between the atoms
# angle_style none
#
# # indicates type of boundary conditions in each direction (p = periodic)
# boundary p p p
#
# read_data ${baseFilename}.LAMMPS_read_data # file of atomic coordinates and topology
# velocity all zero linear                   # initialize all atomic velocities initially to zero
#
# # == Interactions
# pair_style none
# atom_modify sort 1000 ${neighborSkinDist}          # setup sort data explicitly since no interactions to set this data.
#
# # == Setup neighbor list distance
# comm_style tiled
# comm_modify mode single cutoff 18.0 vel yes
#
# neighbor ${neighborSkinDist} bin                    # first number gives a distance beyond the force cut-off ${neighborSkinDist}
# neigh_modify every 1
# atom_modify sort 0 ${neighborSkinDist}           # setup sort data explicitly since no interactions to set this data.
#
# #---------------------------------------------------------
# # == Setup the MLMOD Integrator and Simulation
# fix f1 all mlmod Main.MLMOD_params
#
# m_ids  reset_ids       reset_mol_ids   run             set
# temper/grem     temper/npt      velocity        write_coeff     write_data
# write_dump      write_restart
#
#
#
# Info-Info-Info-Info-Info-Info-Info-Info-Info-Info-Info
#
# Total wall time: 0:00:00
# LAMMPS (29 Oct 2020)
# Reading data file ...
#   triclinic box = (-18.000000 -18.000000 -18.000000) to (18.000000 18.000000 18.000000) with tilt (0.0000000 0.0000000 0.0000000)
#   1 by 1 by 1 MPI processor grid
#   reading atoms ...
#   25 atoms
# Finding 1-2 1-3 1-4 neighbors ...
#   special bond factors lj:    0.0      0.0      0.0
#   special bond factors coul:  0.0      0.0      0.0
#      0 = max # of 1-2 neighbors
#      0 = max # of 1-3 neighbors
#      0 = max # of 1-4 neighbors
#      1 = max # of special neighbors
#   special bonds CPU = 0.005 seconds
#   read_data CPU = 0.010 seconds
# parsing filename = Main.MLMOD_params
# model_data: type = dX_MF_ML1
# model_data: M_ii_filename = M_ii_oseen1.pt
# model_data: M_ij_filename = M_ij_o# == Setup a fixed force acting on subset of particles
# group cforce id 13 # create group using id's
# seen1.pt
# -----------------------------------
# fix f2 cforce addforce 10.0 0.0 0.0 # add force to the cforce group
#
# # note langevin just computes forces, nve integrates the motions
# #fix 1 all langevin 298.15 298.15 0.00001 48279
# #fix 2 all nve
#
# # == Setup output data write to disk
# dump        dmp_vtk_mlmod all vtk ${dumpfreq} ./vtk/Particles_mlmod_*.vtp id type vx fx
# #dump        dmp_vtk_mlmod all vtk ${dumpfreq} ./vtk/Particles_langevin_*.vtp id type vx fx
# dump_modify dmp_vtk_mlmod pad 8 # ensures filenames file_000000.data
#
# # == simulation time-stepping
# timestep 0.35
#
# # == Run the simulation
# run      100 upto
# MLMOD: setmask(), mask = 256
# 1 atoms in group cforce
# MLMOD: init_from_fix
# Neighbor list info ...
#   update every 1 steps, delay 10 steps, check yes
#   max neighbors/atom: 2000, page size: 100000
#   master list distance cutoff = 0
#   ghost atom cutoff = 18
#   binsize = 36, bins = 1 1 1
#   0 neighbor lists, perpetual/occasional/extra = 0 0 0
# Setting up Verlet run ...
#   Unit style    : nano
#   Current step  : 0
#   Time step     : 0.35
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5ddb7bfa0): Error opening output file "./vtk/Particles_mlmod_00000000.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5ddb7bfa0): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de0c4080): Algorithm vtkXMLPolyDataWriter(0x55c5ddb7bfa0) returned failure for request: vtkInformation (0x55c5de0ca4f0)
#   Debug: Off
#   Modified Time: 195
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000000_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de0c3f10): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5dd943250)
#   Debug: Off
#   Modified Time: 460
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
# Per MPI rank memory allocation (min/avg/max) = 3.943 | 3.943 | 3.943 Mbytes
# Step Temp E_pair E_mol TotEng Press
#        0            0            0            0            0            0
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de0c2ee0): Error opening output file "./vtk/Particles_mlmod_00000001.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de0c2ee0): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de0c2ee0) returned failure for request: vtkInformation (0x55c5de2151a0)
#   Debug: Off
#   Modified Time: 698
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000001_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de1d1820)
#   Debug: Off
#   Modified Time: 962
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de0c2ee0): Error opening output file "./vtk/Particles_mlmod_00000002.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de0c2ee0): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de0c2ee0) returned failure for request: vtkInformation (0x55c5de488ba0)
#   Debug: Off
#   Modified Time: 1200
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000002_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de20b630)
#   Debug: Off
#   Modified Time: 1464
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de485d40): Error opening output file "./vtk/Particles_mlmod_00000003.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de485d40): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de485d40) returned failure for request: vtkInformation (0x55c5de40e830)
#   Debug: Off
#   Modified Time: 1702
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000003_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de40b7f0)
#   Debug: Off
#   Modified Time: 1966
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de47dbf0): Error opening output file "./vtk/Particles_mlmod_00000004.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de47dbf0): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de47dbf0) returned failure for request: vtkInformation (0x55c5de40c420)
#   Debug: Off
#   Modified Time: 2204
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000004_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de1fffb0)
#   Debug: Off
#   Modified Time: 2468
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de40f990): Error opening output file "./vtk/Particles_mlmod_00000005.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de40f990): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de40f990) returned failure for request: vtkInformation (0x55c5de479eb0)
#   Debug: Off
#   Modified Time: 2706
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000005_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de40ed20)
#   Debug: Off
#   Modified Time: 2970
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de40e250): Error opening output file "./vtk/Particles_mlmod_00000006.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de40e250): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de40e250) returned failure for request: vtkInformation (0x55c5de414170)
#   Debug: Off
#   Modified Time: 3208
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000006_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de47a430)
#   Debug: Off
#   Modified Time: 3472
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000007.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de46ace0)
#   Debug: Off
#   Modified Time: 3710
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000007_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de476270)
#   Debug: Off
#   Modified Time: 3974
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000008.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de40d9b0)
#   Debug: Off
#   Modified Time: 4212
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000008_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de1fffb0)
#   Debug: Off
#   Modified Time: 4476
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000009.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de476fa0)
#   Debug: Off
#   Modified Time: 4714
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000009_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de34fe70)
#   Debug: Off
#   Modified Time: 4978
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000010.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de417360)
#   Debug: Off
#   Modified Time: 5216
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000010_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de410870)
#   Debug: Off
#   Modified Time: 5480
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000011.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de471e30)
#   Debug: Off
#   Modified Time: 5718
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000011_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de0c6b50)
#   Debug: Off
#   Modified Time: 5982
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000012.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de47aa20)
#   Debug: Off
#   Modified Time: 6220
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000012_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de40dc30)
#   Debug: Off
#   Modified Time: 6484
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000013.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de47ba30)
#   Debug: Off
#   Modified Time: 6722
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000013_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de416ff0)
#   Debug: Off
#   Modified Time: 6986
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000014.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de479ca0)
#   Debug: Off
#   Modified Time: 7224
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000014_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de47c9f0)
#   Debug: Off
#   Modified Time: 7488
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000015.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de40de30)
#   Debug: Off
#   Modified Time: 7726
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000015_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de4107f0)
#   Debug: Off
#   Modified Time: 7990
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000016.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de40aff0)
#   Debug: Off
#   Modified Time: 8228
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000016_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de40ade0)
#   Debug: Off
#   Modified Time: 8492
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000017.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de4170b0)
#   Debug: Off
#   Modified Time: 8730
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000017_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de41cae0)
#   Debug: Off
#   Modified Time: 8994
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000018.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de40df00)
#   Debug: Off
#   Modified Time: 9232
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000018_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de411940)
#   Debug: Off
#   Modified Time: 9496
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000019.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de4749f0)
#   Debug: Off
#   Modified Time: 9734
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000019_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de469810)
#   Debug: Off
#   Modified Time: 9998
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000020.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de47fe40)
#   Debug: Off
#   Modified Time: 10236
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000020_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de410d30)
#   Debug: Off
#   Modified Time: 10500
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000021.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de474730)
#   Debug: Off
#   Modified Time: 10738
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000021_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de1fffb0)
#   Debug: Off
#   Modified Time: 11002
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000022.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de412840)
#   Debug: Off
#   Modified Time: 11240
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000022_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de35d850)
#   Debug: Off
#   Modified Time: 11504
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000023.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de48a7f0)
#   Debug: Off
#   Modified Time: 11742
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000023_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de2d11c0)
#   Debug: Off
#   Modified Time: 12006
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000024.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de40bf70)
#   Debug: Off
#   Modified Time: 12244
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000024_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de411eb0)
#   Debug: Off
#   Modified Time: 12508
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000025.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de4118a0)
#   Debug: Off
#   Modified Time: 12746
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000025_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de40fe30)
#   Debug: Off
#   Modified Time: 13010
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000026.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de40d4f0)
#   Debug: Off
#   Modified Time: 13248
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000026_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de21b000)
#   Debug: Off
#   Modified Time: 13512
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000027.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de486370)
#   Debug: Off
#   Modified Time: 13750
#   Reference Count: 1
# ...
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000091.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de4778b0)
#   Debug: Off
#   Modified Time: 45878
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000091_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de2d11c0)
#   Debug: Off
#   Modified Time: 46142
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000092.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de40f1b0)
#   Debug: Off
#   Modified Time: 46380
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000092_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de411a70)
#   Debug: Off
#   Modified Time: 46644
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000093.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de411080)
#   Debug: Off
#   Modified Time: 46882
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000093_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de40f0f0)
#   Debug: Off
#   Modified Time: 47146
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000094.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de40e1b0)
#   Debug: Off
#   Modified Time: 47384
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000094_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de0c6be0)
#   Debug: Off
#   Modified Time: 47648
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000095.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de474b70)
#   Debug: Off
#   Modified Time: 47886
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000095_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de46a6b0)
#   Debug: Off
#   Modified Time: 48150
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000096.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de4139f0)
#   Debug: Off
#   Modified Time: 48388
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000096_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de0c6be0)
#   Debug: Off
#   Modified Time: 48652
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000097.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de413270)
#   Debug: Off
#   Modified Time: 48890
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000097_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de21b000)
#   Debug: Off
#   Modified Time: 49154
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000098.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de40d5f0)
#   Debug: Off
#   Modified Time: 49392
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000098_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de21b000)
#   Debug: Off
#   Modified Time: 49656
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000099.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de4170b0)
#   Debug: Off
#   Modified Time: 49894
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000099_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de35d850)
#   Debug: Off
#   Modified Time: 50158
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLPolyDataWriter (0x55c5de416870): Error opening output file "./vtk/Particles_mlmod_00000100.vtp"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLPolyDataWriter (0x55c5de416870): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de227f20): Algorithm vtkXMLPolyDataWriter(0x55c5de416870) returned failure for request: vtkInformation (0x55c5de47c270)
#   Debug: Off
#   Modified Time: 50396
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1
#
#
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 739
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error opening output file "./vtk/Particles_mlmod_00000100_boundingBox.vtu"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/IO/XML/vtkXMLWriter.cxx, line 742
# vtkXMLUnstructuredGridWriter (0x55c5ddab4a00): Error code "No such file or directory"
#
# ERROR: In /build/vtk6-mLKLlm/vtk6-6.3.0+dfsg1/Common/ExecutionModel/vtkExecutive.cxx, line 784
# vtkCompositeDataPipeline (0x55c5de455900): Algorithm vtkXMLUnstructuredGridWriter(0x55c5ddab4a00) returned failure for request: vtkInformation (0x55c5de47bf30)
#   Debug: Off
#   Modified Time: 50660
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_DATA
#   FORWARD_DIRECTION: 0
#   FROM_OUTPUT_PORT: -1
#   ALGORITHM_AFTER_FORWARD: 1

# %%
print("Done");
# Out:
# Done
